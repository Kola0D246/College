# %% [markdown]
# # Matplotlib

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import matplotlib.pyplot as plt

year = [2023, 2024, 2025, 2026]     #x-axis
students = [15, 23, 26, 30]         #y-axis

plt.plot(year, students)
plt.show()

# %%
import matplotlib.pyplot as plt

students = [15, 23, 26, 30]         #y-axis

plt.plot(students)          # plot xaxis at interval 1.0
plt.show()
