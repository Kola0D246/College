# %% [markdown]
# Programming Paradigm - style or way of coding
#
# 1. Procedural Programming - step by step execution
# 2. Functional Programming - use function to organise and execute code
# 3. Object-Oriented Programming - use class and objects to organise and execute codes
# 4. Scripting - use to automate simple task by writing small program

# %% [markdown]
# # OOPS
#
# 1. class - Blueprint of creating and using object
# 2. Object - An instance of class. Contains it separate set of instance values and use class values and methods

# %%
class Car:
  def __init__(self, brand, color):
    self.brand = brand
    self.color = color

  def start_engine(self):
    print(f"{self.color} {self.brand} engine started.")


#Creating object
car1 = Car("Toyota", "Red")
car2 = Car("BMW", "BlaCK")

#accessing method and attributes
car1.start_engine()     #Red Toyota engine started.
car2.start_engine()     #Black BMW engine started.

# %%
#Inheritance - single
class Parent:
  pass    #parent class

class Child(Parent):
  pass    #Child class inheriting from Parent class

# %%
class Animal:       #Parent
  def speak(self):
    print("Animal speaks")

class Dog(Animal):  #child
  def bark(self):
    print("Dog barks")

#Create object
d = Dog()
d.speak()
d.bark()

# %%
#Multiple Inheritance

class Father:
  pass    #Parent class 1

class Mother:
  pass    #Parent class 2

class Child(Mother, Father):
  pass    ##Child class inheriting from Mother Class and Father Class

"""
If both parent classes have a method with the same name but different implementations,
and a child class inherits from both
then method resolution order (MRO) - which parent class name is is first as argument -
decides which method is called when invoked from the child

use print(<class name>.__mro__) to see MRO for specific child class
"""

# %%
#Multi-level Inheritance

class Grandparent:
  pass    #Parent class at level 0
          #Inherit nothing

class Parent(Grandparent):
  pass    #Parent class at level 1
          #Inherit from Grandparent class

class child(Parent):
  pass    #Parent class at level 2
          #Inherit from Parent class which inherit from Grandparent class

# %%
#Hierarchical Inheritance

class Parent:
  pass    #Parent class

class Child_1(Parent):
  pass    #Child Class 1 inheriting from same Parent class

class child_2(Parent):
  pass    #Child Class 1 inheriting from same Parent class

# %%
#Overriding

class Animal:       #Parent
  def speak(self):
    print("Animal speaks")

class Dog(Animal):  #child
  def speak(self):  #override
    print("Dog barks")

class Cow(Animal):        #simple inheritance
  pass

#Create object
d = Dog()
d.speak()
c = Cow()
c.speak()

# %%
#Operator Overloading

class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def __mul__(self, scalar):
        return Point(self.x * scalar, self.y * scalar)

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(2, 3)
p2 = Point(4, 5)

print(p1 + p2)     # (6, 8)
print(p1 * 3)      # (6, 9)

# %% [markdown]
# # Data Hiding

# %%
class BankAccount:
  def __init__(self, balance):
    self.__balance = balance    #private variable

  def show_balance(self):
    print("Your balance is:", self.__balance)

#Test
acc = BankAccount(1000)
acc.show_balance()      #Show output

try:
  print(acc.__balance)    #Not show because private variable
except:
  print("Causing error")

# %% [markdown]
# # Error Handling

# %%
try:
    num = float(input("Enter a number: "))
    result = 10 / num
except ZeroDivisionError:        #if num == 0
    print("Cannot divide by zero!")
except ValueError:               #iunini
    print("Invalid input, please enter a number.")

#since no else, the code will run only try statement
print("-" * 30)

# %%
try:
    num = int(input("Enter another number: "))
    result = 10 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input.")
else:
    print("Result is:", result)
print("-" * 30)

# %%
try:
    num = int(input("Enter one more number: "))
    result = 10 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
finally:
    print("This will run no matter what.")
    # print(result/0)   - if there is error code in finaaly, it will raise error
print("-" * 30)
